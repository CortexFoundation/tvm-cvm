# %%
import mxnet as mx
from mxnet import ndarray as nd
from gluoncv.utils import viz

import math

params = nd.load('../../../data/mobilenet1.0_int8.params')
print (params.keys())
# Out:
# dict_keys(['mobilenet0_conv0_weight', 'mobilenet0_batchnorm0_gamma', 'mobilenet0_batchnorm0_beta', 'mobilenet0_conv1_weight', 'mobilenet0_batchnorm1_gamma', 'mobilenet0_batchnorm1_beta', 'mobilenet0_conv2_weight', 'mobilenet0_batchnorm2_gamma', 'mobilenet0_batchnorm2_beta', 'mobilenet0_conv3_weight', 'mobilenet0_batchnorm3_gamma', 'mobilenet0_batchnorm3_beta', 'mobilenet0_conv4_weight', 'mobilenet0_batchnorm4_gamma', 'mobilenet0_batchnorm4_beta', 'mobilenet0_conv5_weight', 'mobilenet0_batchnorm5_gamma', 'mobilenet0_batchnorm5_beta', 'mobilenet0_conv6_weight', 'mobilenet0_batchnorm6_gamma', 'mobilenet0_batchnorm6_beta', 'mobilenet0_conv7_weight', 'mobilenet0_batchnorm7_gamma', 'mobilenet0_batchnorm7_beta', 'mobilenet0_conv8_weight', 'mobilenet0_batchnorm8_gamma', 'mobilenet0_batchnorm8_beta', 'mobilenet0_conv9_weight', 'mobilenet0_batchnorm9_gamma', 'mobilenet0_batchnorm9_beta', 'mobilenet0_conv10_weight', 'mobilenet0_batchnorm10_gamma', 'mobilenet0_batchnorm10_beta', 'mobilenet0_conv
# ...

# %%
params['mobilenet0_conv0_weight']
# Out:
# [[[[ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00]
#    [-0.00000000e+00 -0.00000000e+00 -0.00000000e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00 -0.00000000e+00]
#    [-0.00000000e+00 -0.00000000e+00 -0.00000000e+00]]
#
#   [[-0.00000000e+00 -0.00000000e+00 -0.00000000e+00]
#    [-0.00000000e+00 -0.00000000e+00 -0.00000000e+00]
#    [-0.00000000e+00 -0.00000000e+00 -0.00000000e+00]]]
#
#
#  [[[-8.60595703e-02  2.21099854e-02  6.68334961e-02]
#    [-1.14746094e-01 -1.13769531e-01  1.10397339e-02]
#    [-9.00268555e-03  9.67407227e-02  2.24609375e-02]]
#
#   [[-1.29882812e-01 -4.35256958e-03  6.45141602e-02]
#    [-1.67846680e-01 -1.52221680e-01 -2.21557617e-02]
#    [-6.17370605e-02  1.20666504e-01  4.31823730e-02]]
#
#   [[-2.23388672e-02  1.66473389e-02 -1.52435303e-02]
#    [-2.01416016e-02 -4.21142578e-02 -3.95507812e-02]
# ...
